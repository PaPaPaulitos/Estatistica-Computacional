# %% [markdown]
# <a href="https://colab.research.google.com/github/PaPaPaulitos/Estatistica-Computacional/blob/main/estatistica_qmd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instalando as dependencias do Quarto

# %% [markdown]
# ## Questão 01
#
# A empresa ZZZCORP está planejando lançar um aplicativo para
# smartphones voltado para corredores de rua. A estratégia de lançamento será feita
# cidade a cidade para permitir um crescimento sustentável da infraestrutura.
# Inicialmente, a empresa deseja focar em cinco cidades para decidir qual delas será
# a primeira a receber o lançamento. O ciclo de pesquisa para essa decisão deve ser
# concluído em no máximo um mês, e os recursos para a pesquisa são limitados.
# Qualquer gasto adicional com a pesquisa reduzirá o orçamento disponível para
# anúncios e publicidade
#
# **Objetivo**: A empresa quer entender o perfil dos corredores de rua em cada cidade
# para direcionar seus anúncios de forma eficaz
#
# **Tarefa**: Planeje uma coleta de dados para as cinco cidades selecionadas.
# Especifique as seguintes informações:
#
# a. Quais variáveis de interesse devem ser coletadas?
#
# 𝙍𝙀𝙎𝙋𝙊𝙎𝙏𝘼
#
# - Nome da Pessoa
# - A pessoa é corredor
# - Cidade
# - Gênero
# - Data de nascimento
#
# No ETL a variavel sucinta "A pessoa é corredor" com *Strings* Sim ou Não será transformada em 2 colunas para transformar em valores númericos, o mesmo acontece com *Gênero* e a coluna *Data de nascimento* vai ser gerada uma coluna denominada *idade* em cima dela.
#
# b. Quais métodos estatísticos você usará para analisar os dados coletados? (Ex:média, mediana, desvio padrão, etc.)
#
# 𝙍𝙀𝙎𝙋𝙊𝙎𝙏𝘼
#
# Nos usariamos baseado nas colunas especificadas a cima eu faria a média e o de pessoas corredoras em cada cidade e a idade delas e o desvio-padrão para ver a margem de erro da minha média.
#
# c. Descreva o cronograma e as etapas da pesquisa até sua conclusão.
#
# 𝙍𝙀𝙎𝙋𝙊𝙎𝙏𝘼
#
# Semana 1: Planejamento e Preparação •    Dia 1: Reunião de kickoff para definição de objetivos e escopo. •    Dia 2-3: Identificação das fontes de dados. •    Dia 4-5: Desenvolvimento do plano de coleta de dados. •    Dia 6-7: Revisão e aprovação do plano. Semana 2: Configuração e Preparação Técnica •    Dia 8-9: Configuração de ferramentas e sistemas. •    Dia 10-11: Treinamento da equipe. •    Dia 12: Realização de testes piloto. Semana 2-3-4: Coleta de Dados Analises  •    Dia 13-22: Início da coleta de dados de acordo com o plano. •    Dia 23: Realização de análises preliminares. •    Dia 24-25: Comunicação dos resultados preliminares à equipe de gestão. Semana 4: Relatório e Conclusão •    Dia 26-27: Preparação do relatório final com análises completas e recomendações. •    Dia 28: Revisão do relatório com a equipe de gestão. •    Dia 29: Finalização e entrega do relatório. •    Dia 30: Encerramento do projeto e revisão das lições aprendidas.

# %%
install.packages("tidyverse")
install.packages("palmerpenguins")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# # Declarar as bibliotecas

# %%
library(tidyverse)
library(palmerpenguins)

# %% [markdown]
# ## Questão 02
#
# Faça um programa em R que carregue os dados de mtcars e gere
# um scatterplot de cilindradas e milhas por galão. E descreva as conclusões que
# podem ser tiradas do gráfico.
#
# *a)* PROGRAMA:
# Está abaixo
#
# *b)* SAÍDA (gráfico):
# Está abaixo
#
# *c)* CONCLUSÕES:
# De acordo com o gráfico o número de cilindradas é maior quando o número de milhas é menor.

# %%
# NOT RUN {
require(mtcars)
require(stats)

mpg_var <- mtcars$mpg
cyl_var <- mtcars$cyl


plot(cyl_var,mpg_var,
  main = "Gráfico de Milhas por Galão por Cilindradas",
  xlab =  "Número de Cilindros",
  ylab = "Milhas por Galão",

  pch = 16,
  col = "blue" )
# Out:
# Loading required package: mtcars
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mtcars’”
# Plot with title “Gráfico de Milhas por Galão por Cilindradas”

# %% [markdown]
# ## Questão 03
# Você fez a análise do mercado de imobiliário no RIO de JANEIRO
# e obteve os seguintes, dados relativos ao Preço de APARTAMENTOS de 3
# quartos na Zona Sul da Cidade. Assuma o papel de um consultor de
# investimentos, e descreva como caracterizaria o mercado para o seu cliente.
# Conjunto de dados: valor do metroquadrados de 10 apartamentos em cada
# bairro:
#
# *a)* Você deve usar o R para carregar os dados em um dataframe e assim poder
# fazer sua análise.
#
# *b)* Identifique se existem candidatos a Outliers em cada bairro. Explique a técnica
# usada. Decida se deve excluir, ignorar ou dar um tratamento. Se a opção for
# aplicar um tratamento, explique o tratamento dado.
#
# *c)* Calcule o alcance, média, o desvio padrão, curtose para cada bairro e para
# todos os bairros
#
# *d)* Responda Qual o bairro onde o investimento seria mais seguro e por quê?
#
# *e)* Em qual o bairro o investimento é mais arriscado?
#
# *f)* Em qual o bairro o m2 é mais valorizado?
#
# *g)* Podemos usar o z-score para escolher um imóvel com maior potencial de
# valorização? Qual seria esse imóvel?
#
# *h)* Faça um histograma para cada bairro. Explique as informações relevantes em
# cada um deles.

# %% [markdown]
# ### Carregando dados em Dataframe

# %%
Botafogo <- c(11370, 18510, 12510, 1150, 13000, 13140, 18330, 19750, 20200, 15300)
Ipanema <- c(21504, 22570, 23400, 24030, 18300, 12300, 21600, 36000, 31000, 22100)
Copacabana <- c(10020, 11120, 12900, 22200, 23800, 25200, 13000, 18800, 13200, 11700)
Flamengo <- c(10900, 11700, 13400, 14300, 12380, 11300, 13600, 13200, 20200, 10300)
Gavea <- c(22504, 13700, 11400, 12200, 21820, 22600, 10900, 22000, 13100, 12300)
Leblon <- c(22800, 27700, 23800, 12200, 21900, 22300, 21800, 16100, 22900, 24800)
SaoConrado <- c(11504, 11600, 14400, 21400, 2800, 21300, 11000, 12000, 1800, 11900)
Urca <- c(29504, 22700, 23800, 31100, 11800, 11300, 14600, 24000, 13300, 22900)
Gloria <- c(32504, 25700, 13400, 12400, 11800, 12300, 11600, 16000, 53000, 12100)
Laranjeiras <- c(21004, 11700, 11400, 22400, 12800, 21300, 21600, 13000, 22000, 11100)


dados <- data.frame(
  Botafogo = Botafogo,
  Ipanema = Ipanema,
  Copacabana = Copacabana,
  Flamengo = Flamengo,
  Gavea = Gavea,
  Leblon = Leblon,
  SaoConrado = SaoConrado,
  Urca = Urca,
  Gloria = Gloria,
  Laranjeiras = Laranjeiras
)


print(dados)
# Out:
#    Botafogo Ipanema Copacabana Flamengo Gavea Leblon SaoConrado  Urca Gloria
# 1     11370   21504      10020    10900 22504  22800      11504 29504  32504
# 2     18510   22570      11120    11700 13700  27700      11600 22700  25700
# 3     12510   23400      12900    13400 11400  23800      14400 23800  13400
# 4      1150   24030      22200    14300 12200  12200      21400 31100  12400
# 5     13000   18300      23800    12380 21820  21900       2800 11800  11800
# 6     13140   12300      25200    11300 22600  22300      21300 11300  12300
# 7     18330   21600      13000    13600 10900  21800      11000 14600  11600
# 8     19750   36000      18800    13200 22000  16100      12000 24000  16000
# 9     20200   31000      13200    20200 13100  22900       1800 13300  53000
# 10    15300   22100      11700    10300 12300  24800      11900 22900  12100
#    Laranjeiras
# 1        21004
# 2        11700
# 3        11400
# 4        22400
# 5        12800
# 6        21300
# ...

# %% [markdown]
# ## Verificando Outliers
#
# - Utilizando o gráfico Boxplot que mostra os Outliers.
#
# ## Os bairros
# - Botafogo
# - Ipanema
# - Flamengo
# - Leblon
# - São Conrado
# - Gloria
#
# ### O que faremos com os outliers
#
# A gente vai simplesmte ignorar eles e verificar se os valores dos imoveis batem com a média e estão dentro do desvio-padrão.

# %%
for (coluna in colnames(dados)) {
  valores_coluna <- dados[[coluna]]
  boxplot(valores_coluna, main = paste("Boxplot da coluna:", coluna, "\n"))
}
# Out:
# Plot with title “Boxplot da coluna: Botafogo
# ”
# Plot with title “Boxplot da coluna: Ipanema
# ”
# Plot with title “Boxplot da coluna: Copacabana
# ”
# Plot with title “Boxplot da coluna: Flamengo
# ”
# Plot with title “Boxplot da coluna: Gavea
# ”
# Plot with title “Boxplot da coluna: Leblon
# ”
# Plot with title “Boxplot da coluna: SaoConrado
# ”
# Plot with title “Boxplot da coluna: Urca
# ”
# Plot with title “Boxplot da coluna: Gloria
# ”
# Plot with title “Boxplot da coluna: Laranjeiras
# ”

# %% [markdown]
# ## Calculando o alcance, média, o desvio padrão, curiose

# %%
# Alcance

alcance <- range(dados)

print(dados)
# Out:
#    Botafogo Ipanema Copacabana Flamengo Gavea Leblon SaoConrado  Urca Gloria
# 1     11370   21504      10020    10900 22504  22800      11504 29504  32504
# 2     18510   22570      11120    11700 13700  27700      11600 22700  25700
# 3     12510   23400      12900    13400 11400  23800      14400 23800  13400
# 4      1150   24030      22200    14300 12200  12200      21400 31100  12400
# 5     13000   18300      23800    12380 21820  21900       2800 11800  11800
# 6     13140   12300      25200    11300 22600  22300      21300 11300  12300
# 7     18330   21600      13000    13600 10900  21800      11000 14600  11600
# 8     19750   36000      18800    13200 22000  16100      12000 24000  16000
# 9     20200   31000      13200    20200 13100  22900       1800 13300  53000
# 10    15300   22100      11700    10300 12300  24800      11900 22900  12100
#    Laranjeiras
# 1        21004
# 2        11700
# 3        11400
# 4        22400
# 5        12800
# 6        21300
# ...

# %%
# Media
media <- colMeans(dados)

print(media)
# Out:
#    Botafogo     Ipanema  Copacabana    Flamengo       Gavea      Leblon
#     14326.0     23280.4     16194.0     13128.0     16252.4     21630.0
#  SaoConrado        Urca      Gloria Laranjeiras
#     11970.4     20500.4     20080.4     16830.4

# %%
## Calculando desvio padrão

for (coluna in colnames(dados)) {
  print(coluna)
  desvioPadrao <- sd(dados[[coluna]])
  print(desvioPadrao)
}
# Out:
# [1] "Botafogo"
# [1] 5649.167
# [1] "Ipanema"
# [1] 6456.759
# [1] "Copacabana"
# [1] 5733.9
# [1] "Flamengo"
# [1] 2800.606
# [1] "Gavea"
# [1] 5207.872
# [1] "Leblon"
# [1] 4405.06
# [1] "SaoConrado"
# [1] 6417.833
# [1] "Urca"
# [1] 7258.344
# [1] "Gloria"
# [1] 13558.91
# [1] "Laranjeiras"
# [1] 5136.518

# %%
install.packages("moments")
library(moments)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
## Calculando Curtoses

for (coluna in colnames(dados)) {
  print(coluna)
  desvioPadrao <- kurtosis(dados[[coluna]])
  print(desvioPadrao)
}
# Out:
# [1] "Botafogo"
# [1] 3.982358
# [1] "Ipanema"
# [1] 3.189307
# [1] "Copacabana"
# [1] 1.610224
# [1] "Flamengo"
# [1] 5.232764
# [1] "Gavea"
# [1] 1.213945
# [1] "Leblon"
# [1] 3.386357
# [1] "SaoConrado"
# [1] 2.422541
# [1] "Urca"
# [1] 1.615279
# [1] "Gloria"
# [1] 4.465698
# [1] "Laranjeiras"
# [1] 1.067023

# %% [markdown]
# ### Qual bairro o investimento é mais seguro?
#
# Laranjeiras para ser o bairro mais seguro para investimento, pois os seus preços são os mais próximos entre si, sem ter uma descrepancia alta entre eles.

# %% [markdown]
# ## Qual é o bairro mais arriscado?
#
# 𝙍𝙀𝙎𝙋𝙊𝙎𝙏𝘼
#
# Ipanema, pois a têndencia dos preços do imóvel é que o preço caia.

# %% [markdown]
# ## Qual é o M2 mais valorizado?
#
# 𝙍𝙀𝙎𝙋𝙊𝙎𝙏𝘼
#
# Copacabana é o M2 mais valorizado

# %% [markdown]
# ## Podemos usar o z-score para escolher um imóvel com maior potencial de valorização? Qual seria esse imóvel?
#
# 𝙍𝙀𝙎𝙋𝙊𝙎𝙏𝘼
#
# Não podemos, pois mesmo o Z-score sendo muito útil na estátisca para definir se um valor está muito acima ou muito abaixo do desvio-padrão, o que define se um imóvel vai valorizar são diversas váriaveis.
#
# - Localização
# - Mercado Imobiliário
# - Características do Imóvel
# - Tendências do Mercado
# - Condinções Econômicas
# - Desenvolvimentos futuros
#
# Sendo inviavel descobrir qual imóvel vai valorizar somente com os valores atuais do mercado.

# %%
for (coluna in colnames(dados)) {
  print(coluna)
  zscore <- scale(dados[[coluna]])
  print(zscore)
}
# Out:
# [1] "Botafogo"
#             [,1]
#  [1,] -0.5232629
#  [2,]  0.7406401
#  [3,] -0.3214633
#  [4,] -2.3323791
#  [5,] -0.2347249
#  [6,] -0.2099424
#  [7,]  0.7087770
#  [8,]  0.9601415
#  [9,]  1.0397992
# [10,]  0.1724148
# attr(,"scaled:center")
# [1] 14326
# attr(,"scaled:scale")
# [1] 5649.167
# [1] "Ipanema"
#              [,1]
#  [1,] -0.27512257
#  [2,] -0.11002425
#  [3,]  0.01852323
#  [4,]  0.11609541
#  [5,] -0.77134680
#  [6,] -1.70060565
#  [7,] -0.26025443
#  [8,]  1.96996681
#  [9,]  1.19558444
# [10,] -0.18281619
# attr(,"scaled:center")
# [1] 23280.4
# attr(,"scaled:scale")
# [1] 6456.759
# [1] "Copacabana"
#             [,1]
#  [1,] -1.0767541
#  [2,] -0.8849126
#  [3,] -0.5744781
#  [4,]  1.0474547
#  [5,]  1.3264969
#  [6,]  1.5706588
#  [7,] -0.5570380
#  [8,]  0.4544900
#  [9,] -0.5221577
# [10,] -0.7837598
# attr(,"scaled:center")
# [1] 16194
# attr(,"scaled:scale")
# [1] 5733.9
# [1] "Flamengo"
#              [,1]
#  [1,] -0.79554203
#  [2,] -0.50988959
# ...

# %% [markdown]
# ## Faça um histograma para cada bairro. Explique as informações relevantes em cada um deles.

# %%
for (coluna in colnames(dados)) {
  hist(
    x = dados[[coluna]],
    main = paste("Histograma de", coluna),
    xlab = "Valor",
    ylab = "Quantidade",
    col = "red",
    border = "black",
    breaks = 10
  )
}
# Out:
# Plot with title “Histograma de Botafogo”
# Plot with title “Histograma de Ipanema”
# Plot with title “Histograma de Copacabana”
# Plot with title “Histograma de Flamengo”
# Plot with title “Histograma de Gavea”
# Plot with title “Histograma de Leblon”
# Plot with title “Histograma de SaoConrado”
# Plot with title “Histograma de Urca”
# Plot with title “Histograma de Gloria”
# Plot with title “Histograma de Laranjeiras”
